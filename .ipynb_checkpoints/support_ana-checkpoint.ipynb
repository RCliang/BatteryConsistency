# %% [markdown]
# ## 思路框架
# - 使用normal数据训练预测充放电的t+R的transformer模型
# - 将预测的结果和实际结果的mse作为异常score
# - 将超过异常score阈值的结果验证打了异常标签的车辆

# %%
### 1. 清洗normal数据，分为充电和放电，窗口大小为L，预测长度为R（L指的是SOC百分比）
### X shape: batch_size*time_len*112 Y shape:

# %%
from typing import Any
from torch.utils.data import DataLoader, Dataset
from config import *
import polars as pl
import os
import torch
import torch.nn.functional as F
from data_process_pl import make_label, target_car_dict, get_cycle_charge
import matplotlib.pyplot as plt
from data_process_pl import *

# %%
df_charge = get_charge_data("D3")
df_charge = make_label(df_charge, target_car_dict['D3'])
df_charge = preprocess(df_charge)

# %%
def select_range(df, start, end):
    return df.filter(pl.col('D24_int').is_between(start, end))

# %%
tmp = df_charge.filter(pl.col('cycle')==1)
s = tmp['D24_int'].min()
e = tmp['D24_int'].max()

# %%
for i in df_charge['cycle'].unique():
    tmp = df_charge.filter(pl.col('cycle')==i)
    s = tmp['D24_int'].min()
    e = tmp['D24_int'].max()
    if e-s < 10: continue
    for j in range(s, e-4):
        res = select_range(tmp, j, j+5)
        print(f"mode: {res['D19'].value_counts()}")
        print(f"cycle:{i}, range:{j},{j+5}, shape:{res.shape[0]}")

# %%
target_car_dict = {'D3':'2022-07-28',
                   'D2':'2022-05-20',
                   'D4':'2022-07-25',
                  'D1':'2022-03-14',
                  'D13':'2022-08-03',
                  'D440':'2022-09-06',
                  'D441':'2022-09-13',
                  'D442':'2022-11-21',
                  'D443':'2022-11-17'}

# %%
df_neg1 = pl.read_parquet('processed_data/D280_4_5.parquet')
df_neg2 = pl.read_parquet('processed_data/D246_4_5.parquet')
df_neg3 = pl.read_parquet('processed_data/D296_4_5.parquet')
df_pos = pl.read_parquet('processed_data/D3_4_5.parquet')

# %%
print(df.columns)
# Out:
# ['D141', 'D22', 'D24_int', 'D44', 'D40', 'D41', 'D52', 'D117', 'D133', 'D334', 'D356', 'D290', 'D135_diff', 'D136_diff', 'soc_diff', 'D135_1', 'D135_2', 'D135_3', 'D135_4', 'D135_5', 'D135_6', 'D135_7', 'D135_8', 'D135_9', 'D135_10', 'D135_11', 'D135_12', 'D135_13', 'D135_14', 'D135_15', 'D135_16', 'D135_17', 'D135_18', 'D135_19', 'D135_20', 'D135_21', 'D135_22', 'D135_23', 'D135_24', 'D135_25', 'D135_26', 'D135_27', 'D135_28', 'D135_29', 'D135_30', 'D135_31', 'D135_32', 'D135_33', 'D135_34', 'D135_35', 'D135_36', 'D135_37', 'D135_38', 'D135_39', 'D135_40', 'D135_41', 'D135_42', 'D135_43', 'D135_44', 'D135_45', 'D135_46', 'D135_47', 'D135_48', 'D135_49', 'D135_50', 'D135_51', 'D135_52', 'D135_53', 'D135_54', 'D135_55', 'D135_56', 'D135_57', 'D135_58', 'D135_59', 'D135_60', 'D135_61', 'D135_62', 'D135_63', 'D135_64', 'D135_65', 'D135_66', 'D135_67', 'D135_68', 'D135_69', 'D135_70', 'D135_71', 'D135_72', 'D135_73', 'D135_74', 'D135_75', 'D135_76', 'D135_77', 'D135_78', 'D135_79', 'D135_80', 'D135_81', 'D135_82', 'D135_83', 'D135_84', 'D135_85', 'D135_86', 'D135_87', 'D135_88', 'D135_89', 'D135_90', 'D135_91', 'D135_92', 'D135_93', 'D135_94', 'D135_95', 'D135_96', 'D135_97', 'D135_98', 'D135_99', 'D135_100', 'D135_101', 'D135_102', 'D135_103', 'D135_104', 'D135_105', 'D135_106', 'D135_107', 'D135_108', 'D135_109', 'D135_110', 'D135_111', 'D135_112', 'D136_1', 'D136_2', 'D136_3', 'D136_4', 'D136_5', 'D136_6', 'D136_7', 'D136_8', 'D136_9', 'D136_10', 'D136_11', 'D136_12', 'D136_13', 'D136_14', 'D136_15', 'D136_16', 'D136_17', 'D136_18', 'D136_19', 'D136_20', 'D136_21', 'D136_22', 'D136_23', 'D136_24', 'D136_25', 'D136_26', 'D136_27', 'D136_28', 'D27', 'D135_diff_max', 'D135_std_max', 'D136_diff_max', 'D136_std_max', 'soc_diff_max', 'D135_1_dv', 'D135_2_dv', 'D135_3_dv', 'D135_4_dv', 'D135_5_dv', 'D135_6_dv', 'D135_7_dv', 'D135_8_dv', 'D135_9_dv', 'D135_10_dv', 'D135_11_dv', 'D135_12_dv', 'D135_13_dv', 'D135_14_dv', 'D135_15_dv', 'D135_16_dv', 'D135_17_dv', 'D135_18_dv', 'D135_19_dv', 'D135_20_dv', 'D135_21_dv', 'D135_22_dv', 'D135_23_dv', 'D135_24_dv', 'D135_25_dv', 'D135_26_dv', 'D135_27_dv', 'D135_28_dv', 'D135_29_dv', 'D135_30_dv', 'D135_31_dv', 'D135_32_dv', 'D135_33_dv', 'D135_34_dv', 'D135_35_dv', 'D135_36_dv', 'D135_37_dv', 'D135_38_dv', 'D135_39_dv', 'D135_40_dv', 'D135_41_dv', 'D135_42_dv', 'D135_43_dv', 'D135_44_dv', 'D135_45_dv', 'D135_46_dv', 'D135_47_dv', 'D135_48_dv', 'D135_49_dv', 'D135_50_dv', 'D135_51_dv', 'D135_52_dv', 'D135_53_dv', 'D135_54_dv', 'D135_55_dv', 'D135_56_dv', 'D135_57_dv', 'D135_58_dv', 'D135_59_dv', 'D135_60_dv', 'D135_61_dv', 'D135_62_dv', 'D135_63_dv', 'D135_64_dv', 'D135_65_dv', 'D135_66_dv', 'D135_67_dv', 'D135_68_dv', 'D135_69_dv', 'D135_70_dv', 'D135_71_dv', 'D135_72_dv', 'D135_73_dv', 'D135_74_dv', 'D135_75_dv', 'D135_76_dv', 'D135_77_dv', 'D135_78_dv', 'D135_79_dv', 'D135_80_dv', 'D135_81_dv', 'D135_82_dv', 'D135_83_dv', 'D135_84_dv', 'D135_85_dv', 'D135_86_dv', 'D135_87_dv', 'D135_88_dv', 'D135_89_dv', 'D135_90_dv', 'D135_91_dv', 'D135_92_dv', 'D135_93_dv', 'D135_94_dv', 'D135_95_dv', 'D135_96_dv', 'D135_97_dv', 'D135_98_dv', 'D135_99_dv', 'D135_100_dv', 'D135_101_dv', 'D135_102_dv', 'D135_103_dv', 'D135_104_dv', 'D135_105_dv', 'D135_106_dv', 'D135_107_dv', 'D135_108_dv', 'D135_109_dv', 'D135_110_dv', 'D135_111_dv', 'D135_112_dv', 'label', 'cycle']

# %%
## 入选特征： [f"D135_{i}_dv" for i in range(1,113)], ['D135_diff_max','D135_std_max']

# %%
plt.plot(df_pos.filter(pl.col('label')==1)['D135_diff_max'].to_list()[:500])
# plt.plot(df['D135_2_dv'].to_list()[:500])
plt.plot(df_neg1['D135_diff_max'].to_list()[:500])
plt.plot(df_neg2['D135_diff_max'].to_list()[:500])
plt.plot(df_neg3['D135_diff_max'].to_list()[:500])
plt.show()

# %%
df = pl.read_parquet('data/D296_3.parquet')

# %%
plt.plot(df['D135_diff'].to_list())
plt.show()

# %%
df2 = pl.read_parquet('processed_data/normal_sample/discharge_data/D296_3.parquet')

# %%
plt.plot(df2['D135_diff'].to_list())
plt.show()
